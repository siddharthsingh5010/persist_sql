# %%
# %run "connect_sql.ipynb"

# %%
connect_db('dev')
# Out:
# Successfully connected to database : dev

# %%
show_tables()
# Out:
#         name
# 0       test
# 1  employees

# %%
sql("select * from employees")
# Out:
#     employeeNumber   lastName firstName extension  \
# 0             1056  Patterson      Mary     x4611
# 1             1076   Firrelli      Jeff     x9273
# 2             1088  Patterson   William     x4871
# 3             1102     Bondur    Gerard     x5408
# 4             1143        Bow   Anthony     x5428
# 5             1165   Jennings    Leslie     x3291
# 6             1166   Thompson    Leslie     x4065
# 7             1188   Firrelli     Julie     x2173
# 8             1216  Patterson     Steve     x4334
# 9             1286      Tseng  Foon Yue     x2248
# 10            1323     Vanauf    George     x4102
# 11            1337     Bondur      Loui     x6493
# 12            1370  Hernandez    Gerard     x2028
# 13            1401   Castillo    Pamela     x2759
# 14            1501       Bott     Larry     x2311
# 15            1504      Jones     Barry      x102
# 16            1611     Fixter      Andy      x101
# 17            1612      Marsh     Peter      x102
# ...

# %%
close_connection()
